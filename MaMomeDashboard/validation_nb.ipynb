# %%
import os
import csv
import pandas as pd

# %%
def raw_metrics(doc_name):

    raw_name = doc_name[:-4] + ".txt"

    with open("../docproc/TxtData/" + raw_name) as f:
        raw = f.read()

    raw = raw.lower()
    rawterms = set(raw.split(" "))
    rawcommterms = len(common_member(bacwords, rawterms))

    rawsents = set(raw.split('.'))
    raw_relsents = rel_sents(rawsents, bacwords)

    raw_tup = (rawcommterms, raw_relsents)

    return raw_tup


def sum_metrics(doc_name, bacwords, bert_type, raw_tup):

    suffices = ["_targ_verb", "_full_verb"]

    for suffix in suffices:
        summary_name = doc_name[:-4] + suffix + ".txt"

        if bert_type == "General":
            with open("Summary_BL/" + summary_name, "r") as f:
                summary = f.read()
        else:
            with open("Summary_PM/" + summary_name, "r") as f:
                summary = f.read()

        summary = summary.lower()
        sumterms = set(summary.split(" "))
        sumcomterms = len(common_member(bacwords, sumterms))

        sumsents = set(summary.split())
        sum_relsents = rel_sents(sumsents, bacwords)
        
        if raw_tup[0] != 0:
            prop_terms = sumcomterms / raw_tup[0]
        else:
            prop_terms = None
        
        if raw_tup[1] != 0:
            prop_sents = sum_relsents / raw_tup[1]
        else:
            prop_sents = None
            
        met_list = [prop_terms, prop_sents]

        return met_list


def common_member(a, b):
    a_set = set(a)
    b_set = set(b)

    commterms = ""

    if (a_set & b_set):
        commterms = list(a_set & b_set)

    return commterms


def rel_sents(sents, bacwords):

    counter = 0

    for sent in sents:
        temp = sent.lower()
        if any(check in temp.split(' ') for check in bacwords):
            counter += 1

    return counter

# %%
with open('../docproc/bac_list.csv') as f:
    reader = csv.reader(f)
    blist = list(reader)

bacteria = []

for bac in blist[2:]:
    if len(bac) > 0:
         bacteria += bac[0].split(' ')

bacwords = [word.lower() for word in bacteria if (word.isalpha() and len(word) > 1)]

# %%
articles = sorted(os.listdir("../MaMomePDFs"))

met_dict = {}

# %%
raw_tup = raw_metrics(articles[4])
print(article)
print(raw_tup)
# Out:
# A Review and Tutorial of Machine Learning Methods for Microbiome Host Trait Prediction.pdf
# (7, 19)

# %%
gen_met_dict = {}

for article in articles:
    raw_tup = raw_metrics(article)
    art_mets = sum_metrics(article, bacwords, "General", raw_tup)
    key = article[:-4]
    metlist = ["General"]
    metlist.append(art_mets[0])
    metlist.append(art_mets[1])
    gen_met_dict[key] = metlist

# %%
gen_df = pd.DataFrame.from_dict(gen_met_dict, orient = "index")

gen_df
# Out:
#                                                           0         1  \
# A Review and Tutorial of Machine Learning Metho...  General       NaN
# Association between Polycystic Ovary Syndrome a...  General  0.192308
# Cervicovaginal Microbiome Composition Is Associ...  General  0.666667
# Contributions of Intestinal Bacteria to Nutriti...  General  0.444444
# Diet during Pregnancy and Infancy and the Infan...  General  0.571429
# Diet-Gut Microbiota Interactions and Gestationa...  General  0.500000
# Effect of commercial vaginal products on the gr...  General  1.000000
# Effects of Psychological, Environmental and Phy...  General  0.272727
# Effects of oral probiotic supplements on vagina...  General  0.800000
# Effects of underfeeding and oral vancomycin on ...  General  0.750000
# Estrogen-mediated gut microbiome alterations in...  General       NaN
# Exercise Attenuates PCB-Induced Changes in the ...  General  1.142857
# Generation of genome-scale metabolic reconstruc...  General       NaN
# Gestational shaping of the maternal vaginal mic...  General  1.000000
# Gut_Microbiome_and_Cardiovascular_Diseases          General  0.826087
# Heterogeneity of the gut microbiome in mice_gui...  General  0.272727
# METAGENOMICS- Genomic Analysis of Microbial Com...  General       NaN
# ML_16S rRNA gene sequencing using a k-mer based...  General       NaN
# Microbiome Composition in Pediatric Populations...  General  0.324324
# Microbiome-Based Biomarkers for IBD                 General  0.407407
# Microbiota and Neurodevelopmental Trajectories-...  General  0.857143
# Nature Medicine Volume issue 2019 [doi 10.1038_...  General       NaN
# Naïve Bayesian Classifier for Rapid Assignment ...  General  0.833333
# Pre-Eclampsia- microbiota possibly playing a role   General       NaN
# Precision Nutrition and the Microbiome, Part 1-...  General  0.166667
# Precision Nutrition and the Microbiome, Part 11...  General  0.133333
# Randomized Trial of Lactin-V to Prevent Recurre...  General  1.000000
# Sex-specific impact of asthma during pregnancy ...  General  0.500000
# Shotgun metagenomics, from sampling to sequenci...  General       NaN
# The Computational Diet - A Review of Computatio...  General  1.000000
# The Evolving Microbiome from Pregnancy to Early...  General  0.161290
# The Human Gut Microbiome A Potential Controller...  General  0.750000
# The Human Microbiome-1-s2.0-S189611261730038X-main  General       NaN
# The Maternal Gut Microbiome during Pregnancy        General  0.600000
# The Role of the Gut Microbiome in Predicting Re...  General  0.875000
# The gut microbiome of healthy long‐living people    General       NaN
# The gut microbiome shapes intestinal immune res...  General  0.250000
# The microbiota composition of the offspring of ...  General  0.733333
# The role of probiotics in women with recurrent ...  General  0.600000
# The role of the microbiome for human health fro...  General  0.323529
# Vagina microbiome                                   General  0.052632
# Vaginal microbiota and preterm birth                General  0.285714
# Viome ML Paper-Gut microbiome activity contribu...  General  1.000000
# Zolink - Reimers.2016.JID.CVM.HIV                   General  0.400000
# Zolnik.2016.MolEco.MbiomeDev                        General  0.428571
# acute DSS induced colitis promotes gut microbia...  General  0.666667
# effect of res on gut microbiota and fat storage...  General  0.375000
# fmicb-07-01031                                      General  0.166667
# gut diet epigenetics-CJ(2014)                       General  0.625000
# gut metabolism compoiunds-FM(2016)                  General       NaN
# gut-1000species                                     General  0.098214
# gut_microbiome_preterm_health-s40168-017-0377-0     General  0.700000
# human_microbiome_healthdisease-nihms388822          General  0.076923
# impact of a lactobacilli-containing gel on vulv...  General  0.214286
# inline-supplementary-material-1                     General       NaN
# microorganisms-07-00014                             General  0.225806
# mouse canine human-DMM2015                          General  0.250000
# mouse gut microbiome-IJMM                           General  0.428571
# nihms900158_A Gradient Boosting Machine for Hie...  General       NaN
# vieira2017Influence of Oral and Gut Microbiota ...  General  0.714286
#
#                                                            2
# A Review and Tutorial of Machine Learning Metho...       NaN
# Association between Polycystic Ovary Syndrome a...  0.102041
# Cervicovaginal Microbiome Composition Is Associ...  0.078431
# Contributions of Intestinal Bacteria to Nutriti...  0.363636
# Diet during Pregnancy and Infancy and the Infan...  0.210526
# Diet-Gut Microbiota Interactions and Gestationa...  0.875000
# Effect of commercial vaginal products on the gr...  0.078125
# Effects of Psychological, Environmental and Phy...  0.363636
# Effects of oral probiotic supplements on vagina...  0.312500
# Effects of underfeeding and oral vancomycin on ...  2.190476
# Estrogen-mediated gut microbiome alterations in...       NaN
# Exercise Attenuates PCB-Induced Changes in the ...  1.500000
# Generation of genome-scale metabolic reconstruc...       NaN
# Gestational shaping of the maternal vaginal mic...  2.000000
# Gut_Microbiome_and_Cardiovascular_Diseases          1.000000
# Heterogeneity of the gut microbiome in mice_gui...  0.142857
# METAGENOMICS- Genomic Analysis of Microbial Com...       NaN
# ML_16S rRNA gene sequencing using a k-mer based...       NaN
# Microbiome Composition in Pediatric Populations...  0.146341
# Microbiome-Based Biomarkers for IBD                 0.464286
# Microbiota and Neurodevelopmental Trajectories-...  0.875000
# Nature Medicine Volume issue 2019 [doi 10.1038_...       NaN
# Naïve Bayesian Classifier for Rapid Assignment ...  0.384615
# Pre-Eclampsia- microbiota possibly playing a role        NaN
# Precision Nutrition and the Microbiome, Part 1-...  0.111111
# Precision Nutrition and the Microbiome, Part 11...  0.071429
# Randomized Trial of Lactin-V to Prevent Recurre...  0.136364
# Sex-specific impact of asthma during pregnancy ...  0.148148
# Shotgun metagenomics, from sampling to sequenci...       NaN
# The Computational Diet - A Review of Computatio...  1.000000
# The Evolving Microbiome from Pregnancy to Early...  0.181818
# The Human Gut Microbiome A Potential Controller...  2.666667
# The Human Microbiome-1-s2.0-S189611261730038X-main       NaN
# The Maternal Gut Microbiome during Pregnancy        0.600000
# The Role of the Gut Microbiome in Predicting Re...  0.636364
# The gut microbiome of healthy long‐living people         NaN
# The gut microbiome shapes intestinal immune res...  0.181818
# The microbiota composition of the offspring of ...  0.413793
# The role of probiotics in women with recurrent ...  0.117647
# The role of the microbiome for human health fro...  0.309524
# Vagina microbiome                                   0.048780
# Vaginal microbiota and preterm birth                0.216216
# Viome ML Paper-Gut microbiome activity contribu...  1.000000
# Zolink - Reimers.2016.JID.CVM.HIV                   0.057143
# Zolnik.2016.MolEco.MbiomeDev                        0.333333
# acute DSS induced colitis promotes gut microbia...  0.357143
# effect of res on gut microbiota and fat storage...  0.272727
# fmicb-07-01031                                      0.111111
# gut diet epigenetics-CJ(2014)                       0.625000
# gut metabolism compoiunds-FM(2016)                       NaN
# gut-1000species                                     0.057034
# gut_microbiome_preterm_health-s40168-017-0377-0     1.142857
# human_microbiome_healthdisease-nihms388822          0.050000
# impact of a lactobacilli-containing gel on vulv...  0.061224
# inline-supplementary-material-1                          NaN
# microorganisms-07-00014                             0.177778
# mouse canine human-DMM2015                          0.222222
# mouse gut microbiome-IJMM                           0.555556
# nihms900158_A Gradient Boosting Machine for Hie...       NaN
# vieira2017Influence of Oral and Gut Microbiota ...  1.000000

# %%
pm_met_dict = {}

for article in articles:
    raw_tup = raw_metrics(article)
    art_mets = sum_metrics(article, bacwords, "PubMed", raw_tup)
    key = article[:-4]
    metlist = ["PubMed"]
    metlist.append(art_mets[0])
    metlist.append(art_mets[1])
    pm_met_dict[key] = metlist

# %%
pm_df = pd.DataFrame.from_dict(pm_met_dict, orient='index')
pm_df
# Out:
#                                                          0         1         2
# A Review and Tutorial of Machine Learning Metho...  PubMed       NaN       NaN
# Association between Polycystic Ovary Syndrome a...  PubMed  0.230769  0.142857
# Cervicovaginal Microbiome Composition Is Associ...  PubMed  0.333333  0.058824
# Contributions of Intestinal Bacteria to Nutriti...  PubMed  0.333333  0.272727
# Diet during Pregnancy and Infancy and the Infan...  PubMed  0.571429  0.210526
# Diet-Gut Microbiota Interactions and Gestationa...  PubMed  0.500000  0.875000
# Effect of commercial vaginal products on the gr...  PubMed  0.600000  0.046875
# Effects of Psychological, Environmental and Phy...  PubMed  0.181818  0.181818
# Effects of oral probiotic supplements on vagina...  PubMed  1.000000  0.375000
# Effects of underfeeding and oral vancomycin on ...  PubMed  0.750000  0.904762
# Estrogen-mediated gut microbiome alterations in...  PubMed       NaN       NaN
# Exercise Attenuates PCB-Induced Changes in the ...  PubMed  1.142857  1.500000
# Generation of genome-scale metabolic reconstruc...  PubMed       NaN       NaN
# Gestational shaping of the maternal vaginal mic...  PubMed  1.000000  2.000000
# Gut_Microbiome_and_Cardiovascular_Diseases          PubMed  0.782609  0.954545
# Heterogeneity of the gut microbiome in mice_gui...  PubMed  0.272727  0.190476
# METAGENOMICS- Genomic Analysis of Microbial Com...  PubMed       NaN       NaN
# ML_16S rRNA gene sequencing using a k-mer based...  PubMed       NaN       NaN
# Microbiome Composition in Pediatric Populations...  PubMed  0.378378  0.195122
# Microbiome-Based Biomarkers for IBD                 PubMed  0.259259  0.250000
# Microbiota and Neurodevelopmental Trajectories-...  PubMed  0.857143  0.875000
# Nature Medicine Volume issue 2019 [doi 10.1038_...  PubMed       NaN       NaN
# Naïve Bayesian Classifier for Rapid Assignment ...  PubMed  0.333333  0.153846
# Pre-Eclampsia- microbiota possibly playing a role   PubMed       NaN       NaN
# Precision Nutrition and the Microbiome, Part 1-...  PubMed  0.148148  0.088889
# Precision Nutrition and the Microbiome, Part 11...  PubMed  0.283333  0.169643
# Randomized Trial of Lactin-V to Prevent Recurre...  PubMed  1.000000  0.136364
# Sex-specific impact of asthma during pregnancy ...  PubMed  0.500000  0.148148
# Shotgun metagenomics, from sampling to sequenci...  PubMed       NaN       NaN
# The Computational Diet - A Review of Computatio...  PubMed  1.000000  1.000000
# The Evolving Microbiome from Pregnancy to Early...  PubMed  0.354839  0.363636
# The Human Gut Microbiome A Potential Controller...  PubMed  0.750000  2.666667
# The Human Microbiome-1-s2.0-S189611261730038X-main  PubMed       NaN       NaN
# The Maternal Gut Microbiome during Pregnancy        PubMed  1.000000  1.000000
# The Role of the Gut Microbiome in Predicting Re...  PubMed  0.875000  0.727273
# The gut microbiome of healthy long‐living people    PubMed       NaN       NaN
# The gut microbiome shapes intestinal immune res...  PubMed  0.333333  0.181818
# The microbiota composition of the offspring of ...  PubMed  0.533333  0.275862
# The role of probiotics in women with recurrent ...  PubMed  0.800000  0.117647
# The role of the microbiome for human health fro...  PubMed  0.382353  0.404762
# Vagina microbiome                                   PubMed  0.105263  0.048780
# Vaginal microbiota and preterm birth                PubMed  0.523810  0.351351
# Viome ML Paper-Gut microbiome activity contribu...  PubMed  1.000000  1.000000
# Zolink - Reimers.2016.JID.CVM.HIV                   PubMed  0.600000  0.085714
# Zolnik.2016.MolEco.MbiomeDev                        PubMed  0.142857  0.111111
# acute DSS induced colitis promotes gut microbia...  PubMed  0.666667  0.285714
# effect of res on gut microbiota and fat storage...  PubMed  0.250000  0.363636
# fmicb-07-01031                                      PubMed  0.166667  0.083333
# gut diet epigenetics-CJ(2014)                       PubMed  0.625000  0.625000
# gut metabolism compoiunds-FM(2016)                  PubMed       NaN       NaN
# gut-1000species                                     PubMed  0.089286  0.041825
# gut_microbiome_preterm_health-s40168-017-0377-0     PubMed  0.800000  1.285714
# human_microbiome_healthdisease-nihms388822          PubMed  0.307692  0.250000
# impact of a lactobacilli-containing gel on vulv...  PubMed  0.357143  0.102041
# inline-supplementary-material-1                     PubMed       NaN       NaN
# microorganisms-07-00014                             PubMed  0.225806  0.200000
# mouse canine human-DMM2015                          PubMed  0.250000  0.222222
# mouse gut microbiome-IJMM                           PubMed  0.428571  0.555556
# nihms900158_A Gradient Boosting Machine for Hie...  PubMed       NaN       NaN
# vieira2017Influence of Oral and Gut Microbiota ...  PubMed  0.857143  1.200000
