# %%
import os
import csv
import pandas as pd

# %%
def raw_metrics(doc_name):

    raw_name = doc_name[:-4] + ".txt"

    with open("../docproc/TxtData/" + raw_name) as f:
        raw = f.read()

    raw = raw.lower()
    rawterms = set(raw.split(" "))
    rawcommterms = len(common_member(bacwords, rawterms))

    rawsents = set(raw.split('.'))
    raw_relsents = rel_sents(rawsents, bacwords)

    raw_tup = (rawcommterms, raw_relsents)

    return raw_tup


def sum_metrics(doc_name, suffix, bacwords, bert_type, raw_tup):

    summary_name = doc_name[:-4] + suffix + ".txt"

    if bert_type == "General":
        with open("Summary_BL/" + summary_name, "r") as f:
            summary = f.read()
    else:
        with open("Summary_PM/" + summary_name, "r") as f:
            summary = f.read()

    summary = summary.lower()
    sumterms = set(summary.split(" "))
    sumcomterms = len(common_member(bacwords, sumterms))

    sumsents = set(summary.split())
    sum_relsents = rel_sents(sumsents, bacwords)

    if raw_tup[0] != 0:
        prop_terms = sumcomterms / raw_tup[0]
    else:
        prop_terms = None

    if raw_tup[1] != 0:
        prop_sents = sum_relsents / raw_tup[1]
    else:
        prop_sents = None

    met_list = [suffix, prop_terms, prop_sents]

    return met_list


def common_member(a, b):
    a_set = set(a)
    b_set = set(b)

    commterms = ""

    if (a_set & b_set):
        commterms = list(a_set & b_set)

    return commterms


def rel_sents(sents, bacwords):

    counter = 0

    for sent in sents:
        temp = sent.lower()
        if any(check in temp.split(' ') for check in bacwords):
            counter += 1

    return counter

# %%
with open('../docproc/bac_list.csv') as f:
    reader = csv.reader(f)
    blist = list(reader)

bacteria = []

for bac in blist[2:]:
    if len(bac) > 0:
         bacteria += bac[0].split(' ')

bacwords = [word.lower() for word in bacteria if (word.isalpha() and len(word) > 1)]

# %%
articles = sorted(os.listdir("../MaMomePDFs"))

met_dict = {}

# %%
raw_tup = raw_metrics(articles[4])
print(article)
print(raw_tup)
# Out:
# A Review and Tutorial of Machine Learning Methods for Microbiome Host Trait Prediction.pdf
# (7, 19)

# %%
gen_met_dict = {}

for article in articles:
    raw_tup = raw_metrics(article)
    suffices = ["_targ_verb", "_full_verb"]
    for suffix in suffices:
        art_mets = sum_metrics(article, suffix, bacwords, "General", raw_tup)
        key = article[:-4] + "_" + art_mets[0]
        metlist = ["General"]
        metlist.append(art_mets[0])
        metlist.append(art_mets[1])
        metlist.append(art_mets[2])
        gen_met_dict[key] = metlist

# %%
gen_df = pd.DataFrame.from_dict(gen_met_dict, orient = "index")

gen_df
# Out:
#                                                           0           1  \
# A Review and Tutorial of Machine Learning Metho...  General  _targ_verb
# A Review and Tutorial of Machine Learning Metho...  General  _full_verb
# Association between Polycystic Ovary Syndrome a...  General  _targ_verb
# Association between Polycystic Ovary Syndrome a...  General  _full_verb
# Cervicovaginal Microbiome Composition Is Associ...  General  _targ_verb
# ...                                                     ...         ...
# mouse gut microbiome-IJMM__full_verb                General  _full_verb
# nihms900158_A Gradient Boosting Machine for Hie...  General  _targ_verb
# nihms900158_A Gradient Boosting Machine for Hie...  General  _full_verb
# vieira2017Influence of Oral and Gut Microbiota ...  General  _targ_verb
# vieira2017Influence of Oral and Gut Microbiota ...  General  _full_verb
#
#                                                            2         3
# A Review and Tutorial of Machine Learning Metho...       NaN       NaN
# A Review and Tutorial of Machine Learning Metho...       NaN       NaN
# Association between Polycystic Ovary Syndrome a...  0.192308  0.102041
# Association between Polycystic Ovary Syndrome a...  0.076923  0.040816
# Cervicovaginal Microbiome Composition Is Associ...  0.666667  0.078431
# ...                                                      ...       ...
# mouse gut microbiome-IJMM__full_verb                0.428571  0.555556
# nihms900158_A Gradient Boosting Machine for Hie...       NaN       NaN
# nihms900158_A Gradient Boosting Machine for Hie...       NaN       NaN
# vieira2017Influence of Oral and Gut Microbiota ...  0.714286  1.000000
# vieira2017Influence of Oral and Gut Microbiota ...  0.000000  0.400000
#
# [120 rows x 4 columns]

# %%
pm_met_dict = {}

for article in articles:
    raw_tup = raw_metrics(article)
    suffices = ["_targ_verb", "_full_verb"]
    for suffix in suffices:
        art_mets = sum_metrics(article, suffix, bacwords, "PubMed", raw_tup)
        key = article[:-4] + "_" + art_mets[0]
        metlist = ["PubMed"]
        metlist.append(art_mets[0])
        metlist.append(art_mets[1])
        metlist.append(art_mets[2])
        pm_met_dict[key] = metlist

# %%
pm_df = pd.DataFrame.from_dict(pm_met_dict, orient='index')
pm_df
# Out:
#                                                          0           1  \
# A Review and Tutorial of Machine Learning Metho...  PubMed  _targ_verb
# A Review and Tutorial of Machine Learning Metho...  PubMed  _full_verb
# Association between Polycystic Ovary Syndrome a...  PubMed  _targ_verb
# Association between Polycystic Ovary Syndrome a...  PubMed  _full_verb
# Cervicovaginal Microbiome Composition Is Associ...  PubMed  _targ_verb
# ...                                                    ...         ...
# mouse gut microbiome-IJMM__full_verb                PubMed  _full_verb
# nihms900158_A Gradient Boosting Machine for Hie...  PubMed  _targ_verb
# nihms900158_A Gradient Boosting Machine for Hie...  PubMed  _full_verb
# vieira2017Influence of Oral and Gut Microbiota ...  PubMed  _targ_verb
# vieira2017Influence of Oral and Gut Microbiota ...  PubMed  _full_verb
#
#                                                            2         3
# A Review and Tutorial of Machine Learning Metho...       NaN       NaN
# A Review and Tutorial of Machine Learning Metho...       NaN       NaN
# Association between Polycystic Ovary Syndrome a...  0.230769  0.142857
# Association between Polycystic Ovary Syndrome a...  0.076923  0.040816
# Cervicovaginal Microbiome Composition Is Associ...  0.333333  0.058824
# ...                                                      ...       ...
# mouse gut microbiome-IJMM__full_verb                0.428571  0.444444
# nihms900158_A Gradient Boosting Machine for Hie...       NaN       NaN
# nihms900158_A Gradient Boosting Machine for Hie...       NaN       NaN
# vieira2017Influence of Oral and Gut Microbiota ...  0.857143  1.200000
# vieira2017Influence of Oral and Gut Microbiota ...  0.142857  0.400000
#
# [120 rows x 4 columns]

# %%
gen_df.columns = ["BERT", "SummaryType", "PropBacTerms", "PropBacSents"]
pm_df.columns = ["BERT", "SummaryType", "PropBacTerms", "PropBacSents"]
